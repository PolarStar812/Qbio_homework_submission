# %%
# !ls
# Out:
# Qbio_homework_submission

# %%
# !pwd
# Out:
# /Users/wuhan/Documents/2class/定量生物学/Qbio

# %%
# %cd Qbio_homework_submission/homework
# Out:
# /Users/wuhan/Documents/2class/定量生物学/Qbio/Qbio_homework_submission/homework
# /opt/miniconda3/envs/quantbio/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !ls
# Out:
# fluorescence_data.csv homework_1.ipynb

# %% [markdown]
# # Module 1 Problem: GFP Fluorescence Analysis
#
# ## 1. Data Loading
#
# The fluorescence dataset was loaded using NumPy. The first column represents time in minutes, and the second column represents GFP fluorescence intensity in arbitrary units (A.U.).

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = 'fluorescence_data.csv'

data = np.loadtxt(filename, delimiter=',', skiprows=1)

time = data[:, 0]
fluorescence = data[:, 1]

print("Data shape:", data.shape)
print("First 5 rows:")
print(data[:5])
# Out:
# Data shape: (121, 2)
# First 5 rows:
# [[0. 1.]
#  [1. 2.]
#  [2. 0.]
#  [3. 0.]
#  [4. 3.]]

# %% [markdown]
# ## 2. Fluorescence Time Course
#
# GFP fluorescence was plotted as a function of time after induction.
